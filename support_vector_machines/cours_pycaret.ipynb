# %% [markdown]
# ## Pycaret et AutoML

# %% [markdown]
# **PyCaret** est une bibliothèque d'**AutoML** (Apprentissage Automatique Automatisé).

# %% [markdown]
# L'AutoML vise à **automatiser le processus de construction, de formation et de déploiement de modèles d'apprentissage automatique**, simplifiant ainsi le travail du data scientist et réduisant la nécessité d'une expertise approfondie en la matière.

# %% [markdown]
# #### Qu'est-ce que Pycaret?

# %% [markdown]
#     PyCaret est une bibliothèque Python conçue pour faciliter le flux de travail de l'apprentissage automatique.
#     Elle offre une interface simple et unifiée pour plusieurs tâches d'apprentissage automatique, de la préparation des données à la création de modèles et à l'évaluation des performances.
#     PyCaret prend en charge divers types de modèles, notamment la classification, la régression, le regroupement, etc.
#
# Documentation officielle : https://pycaret.readthedocs.io/en/stable/api/classification.html

# %% [markdown]
# #### Qu'est-ce que l'AutoML?

# %% [markdown]
#     L'AutoML automatise plusieurs étapes du processus d'apprentissage automatique, telles que la sélection de modèles, l'optimisation des hyperparamètres et la validation croisée.
#     Cela permet aux praticiens qui ne sont pas des experts en apprentissage automatique de créer rapidement des modèles performants sans avoir besoin d'une expertise approfondie.

# %% [markdown]
# #### Utilisation de PyCaret pour l'AutoML

# %% [markdown]
#     PyCaret simplifie l'utilisation de l'AutoML en fournissant des fonctions prêtes à l'emploi pour la préparation des données, la création de modèles, l'évaluation des performances, etc.
#     Il vous permet de spécifier les tâches que vous souhaitez effectuer et effectue automatiquement les étapes nécessaires en coulisses.

# %% [markdown]
# ##### Import des librairies et packages

# %%
# IMPORT DES LIBRAIRIES & PACKAGE
from pycaret.classification import *
import pycaret

# %% [markdown]
# ### Principaux concepts :
#
# 1. **Setup :**
#
#    Le premier pas avec PyCaret consiste à utiliser la fonction `setup()` pour configurer votre environnement de modélisation. Elle prend en charge divers paramètres, notamment les données, la cible, le type de problème (classification ou régression), etc.

# %% [markdown]
# ##### Afficher la version de Pycaret

# %%
print(f"Pycaret version : {pycaret.__version__}")
# Out:
# Pycaret version : 3.2.0

# %% [markdown]
# ##### Création d'un environnement Pycaret

# %% [markdown]
# PyCaret offre une grande facilité d'utilisation en automatisant de nombreuses étapes du processus de modélisation, y compris le prétraitement des données. Cependant, il est important de noter que PyCaret effectue automatiquement certaines étapes de prétraitement, mais pas toutes.
#
# Voici ce que PyCaret fait automatiquement en termes de prétraitement des données lors de l'utilisation de la fonction `setup` :
#
# 1. **Gestion des données manquantes :** PyCaret gère automatiquement les valeurs manquantes en appliquant différentes stratégies en fonction du type de données (numériques ou catégoriques).
#
# 2. **Encodage des variables catégoriques :** PyCaret encode automatiquement les variables catégoriques en utilisant des techniques appropriées pour chaque type de modèle.
#
# 3. **Normalisation/Standardisation :** La normalisation (mise à l'échelle des valeurs entre 0 et 1) est appliquée automatiquement par défaut, sauf si vous spécifiez autrement dans les paramètres de `setup`.
#
# Cependant, il y a des étapes de prétraitement que PyCaret n'effectue pas automatiquement, et qui peuvent nécessiter une attention préalable de votre part, telles que :
#
# 1. **Suppression des colonnes inutiles :** Vous devriez effectuer cette étape avant d'utiliser PyCaret si votre jeu de données contient des colonnes inutiles ou des colonnes qui ne contribuent pas à la prédiction.
#
# 2. **Gestion des valeurs aberrantes :** Si votre jeu de données contient des valeurs aberrantes, vous pouvez avoir besoin de les gérer avant d'utiliser PyCaret. PyCaret propose des fonctionnalités pour détecter les valeurs aberrantes, mais vous pouvez également choisir de traiter les valeurs aberrantes à l'avance.
#
# 3. **Ingénierie des caractéristiques :** Si vous souhaitez créer de nouvelles caractéristiques ou transformer les caractéristiques existantes, vous devriez le faire avant d'utiliser PyCaret.
#
# 4. **Gestion des classes déséquilibrées :** Si votre problème de classification implique des classes déséquilibrées, vous pouvez avoir besoin de prendre des mesures pour gérer cela avant l'utilisation de PyCaret.
#
# En résumé, bien que PyCaret automatisera de nombreuses étapes de prétraitement des données, il est toujours important de comprendre les besoins spécifiques de votre jeu de données et d'effectuer tout prétraitement nécessaire avant d'utiliser PyCaret. La fonction `setup` de PyCaret offre également des paramètres qui vous permettent de personnaliser davantage le prétraitement des données selon vos besoins.

# %%
from pycaret.classification import *
from sklearn import datasets
import pandas as pd

# Charger l'ensemble de données Iris
iris = datasets.load_iris()

# Spécifier la colonne cible (target) dans l'ensemble de données Iris
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target

# Initialisation l'environnement PyCaret en spécifiant la colonne cible
session = setup(data=iris_df, target='target', normalize=True, train_size=0.7, data_split_stratify=True, fold=5, session_id=0)
# Out:
# <style type="text/css">
# #T_6b483_row8_col1, #T_6b483_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6b483">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b483_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6b483_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b483_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b483_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6b483_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6b483_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6b483_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6b483_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6b483_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6b483_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_6b483_row3_col1" class="data row3 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6b483_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_6b483_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6b483_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_6b483_row5_col1" class="data row5 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6b483_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_6b483_row6_col1" class="data row6 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6b483_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_6b483_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6b483_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_6b483_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6b483_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_6b483_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6b483_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_6b483_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6b483_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_6b483_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6b483_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_6b483_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6b483_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_6b483_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6b483_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_6b483_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6b483_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_6b483_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6b483_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_6b483_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6b483_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_6b483_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6b483_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_6b483_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6b483_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_6b483_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6b483_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_6b483_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_6b483_row20_col1" class="data row20 col1" >6c03</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# PyCaret est une bibliothèque open-source en Python conçue pour simplifier le processus de développement de modèles de machine learning. Elle vise à automatiser de nombreuses tâches courantes, telles que la préparation des données, le choix des modèles, l'ajustement des hyperparamètres, l'évaluation des performances et la création de visualisations.
#
# - `target='target'`: Indique la variable cible (ou étiquette) que vous essayez de prédire. Dans cet exemple, la variable cible est appelée 'target'.
#
# - `normalize=True`: Normalise les données. Cela signifie que les valeurs des caractéristiques seront mises à l'échelle pour avoir une moyenne de zéro et un écart type de un. Cela est souvent utile car certains algorithmes de machine learning peuvent être sensibles aux différentes échelles des caractéristiques.
#
# - `train_size=0.7`: Spécifie la proportion des données à utiliser pour l'ensemble d'entraînement. Dans cet exemple, 70% des données seront utilisées pour l'entraînement.
#
# - `data_split_stratify=True`: Effectue une stratification lors de la division des données en ensembles d'entraînement et de test. La stratification est importante pour maintenir la distribution des classes dans les deux ensembles, ce qui est crucial pour certains problèmes de classification.
#
# - `fold=5`: Indique le nombre de plis à utiliser lors de la validation croisée. Dans cet exemple, la validation croisée sera effectuée avec 5 plis.
#
# - `session_id=0`: Fournit un identifiant de session pour la reproductibilité. En fixant cet identifiant, vous pouvez obtenir les mêmes résultats lors de l'exécution ultérieure du code.
#
# En résumé, l'appel à `setup` dans PyCaret permet de configurer l'environnement de travail, de prétraiter les données, de diviser les données en ensembles d'entraînement et de test, et de définir d'autres paramètres importants pour le développement du modèle. Une fois que l'environnement est configuré, vous pouvez utiliser d'autres fonctionnalités de PyCaret pour explorer, comparer et évaluer différents modèles de machine learning.

# %% [markdown]
# ##### Affichage des algorithmes

# %%
algo = models()
print(algo)
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %% [markdown]
# L'option "Turbo" de PyCaret inclut les modèles les plus performants et rapides pour une variété de tâches de machine learning. Ces modèles sont choisis en fonction de leur performance générale sur différentes tâches, et PyCaret ajuste automatiquement les hyperparamètres pour améliorer leur performance.

# %% [markdown]
# ##### Comparer et sélectionner les modèles

# %%
from pycaret.classification import compare_models
top_models = compare_models(n_select=3, sort="Accuracy")
print(top_models)
# Out:
# <style type="text/css">
# #T_88728 th {
#   text-align: left;
# }
# #T_88728_row0_col0, #T_88728_row1_col0, #T_88728_row1_col1, #T_88728_row1_col3, #T_88728_row1_col4, #T_88728_row1_col5, #T_88728_row1_col6, #T_88728_row1_col7, #T_88728_row2_col0, #T_88728_row2_col1, #T_88728_row2_col2, #T_88728_row2_col3, #T_88728_row2_col4, #T_88728_row2_col5, #T_88728_row2_col6, #T_88728_row2_col7, #T_88728_row3_col0, #T_88728_row3_col1, #T_88728_row3_col2, #T_88728_row3_col3, #T_88728_row3_col4, #T_88728_row3_col5, #T_88728_row3_col6, #T_88728_row3_col7, #T_88728_row4_col0, #T_88728_row4_col1, #T_88728_row4_col2, #T_88728_row4_col3, #T_88728_row4_col4, #T_88728_row4_col5, #T_88728_row4_col6, #T_88728_row4_col7, #T_88728_row5_col0, #T_88728_row5_col1, #T_88728_row5_col2, #T_88728_row5_col3, #T_88728_row5_col4, #T_88728_row5_col5, #T_88728_row5_col6, #T_88728_row5_col7, #T_88728_row6_col0, #T_88728_row6_col1, #T_88728_row6_col2, #T_88728_row6_col3, #T_88728_row6_col4, #T_88728_row6_col5, #T_88728_row6_col6, #T_88728_row6_col7, #T_88728_row7_col0, #T_88728_row7_col1, #T_88728_row7_col2, #T_88728_row7_col3, #T_88728_row7_col4, #T_88728_row7_col5, #T_88728_row7_col6, #T_88728_row7_col7, #T_88728_row8_col0, #T_88728_row8_col1, #T_88728_row8_col2, #T_88728_row8_col3, #T_88728_row8_col4, #T_88728_row8_col5, #T_88728_row8_col6, #T_88728_row8_col7, #T_88728_row9_col0, #T_88728_row9
col8" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_88728_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_88728_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_88728_row3_col1" class="data row3 col1" >0.9524</td>
#       <td id="T_88728_row3_col2" class="data row3 col2" >0.9878</td>
#       <td id="T_88728_row3_col3" class="data row3 col3" >0.9524</td>
#       <td id="T_88728_row3_col4" class="data row3 col4" >0.9560</td>
#       <td id="T_88728_row3_col5" class="data row3 col5" >0.9522</td>
#       <td id="T_88728_row3_col6" class="data row3 col6" >0.9286</td>
#       <td id="T_88728_row3_col7" class="data row3 col7" >0.9305</td>
#       <td id="T_88728_row3_col8" class="data row3 col8" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_88728_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_88728_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_88728_row4_col1" class="data row4 col1" >0.9429</td>
#       <td id="T_88728_row4_col2" class="data row4 col2" >0.9939</td>
#       <td id="T_88728_row4_col3" class="data row4 col3" >0.9429</td>
#       <td id="T_88728_row4_col4" class="data row4 col4" >0.9476</td>
#       <td id="T_88728_row4_col5" class="data row4 col5" >0.9427</td>
#       <td id="T_88728_row4_col6" class="data row4 col6" >0.9143</td>
#       <td id="T_88728_row4_col7" class="data row4 col7" >0.9168</td>
#       <td id="T_88728_row4_col8" class="data row4 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_88728_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_88728_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_88728_row5_col1" class="data row5 col1" >0.9429</td>
#       <td id="T_88728_row5_col2" class="data row5 col2" >0.9946</td>
#       <td id="T_88728_row5_col3" class="data row5 col3" >0.9429</td>
#       <td id="T_88728_row5_col4" class="data row5 col4" >0.9495</td>
#       <td id="T_88728_row5_col5" class="data row5 col5" >0.9424</td>
#       <td id="T_88728_row5_col6" class="data row5 col6" >0.9143</td>
#       <td id="T_88728_row5_col7" class="data row5 col7" >0.9179</td>
#       <td id="T_88728_
# [QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001), LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001), DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        random_state=0, splitter='best')]

# %% [markdown]
# PyCaret utilise une approche de recherche automatisée des hyperparamètres pour ajuster les modèles. Plus précisément, PyCaret utilise une méthode appelée **"Random Grid Search"** pour explorer l'espace des hyperparamètres. L'idée est de définir une grille (ensemble) d'hyperparamètres possibles pour chaque modèle, puis de tirer aléatoirement des combinaisons d'hyperparamètres dans cette grille et d'évaluer les performances du modèle avec ces paramètres.
#
# Voici comment le processus se déroule en général dans PyCaret :
#
# 1. **Définition de la grille d'hyperparamètres :** PyCaret pré-définit une grille d'hyperparamètres possible pour chaque modèle. Cette grille est généralement assez étendue pour couvrir un large éventail de valeurs possibles pour chaque hyperparamètre.
#
# 2. **Recherche aléatoire :** PyCaret sélectionne aléatoirement des combinaisons d'hyperparamètres à partir de la grille pour chaque modèle. Cela permet d'explorer efficacement l'espace des hyperparamètres sans avoir à tester toutes les combinaisons possibles, ce qui serait souvent trop coûteux en termes de temps de calcul.
#
# 3. **Évaluation des performances :** Pour chaque combinaison d'hyperparamètres, PyCaret ajuste le modèle sur un sous-ensemble des données d'entraînement et évalue ses performances sur un ensemble de validation (ou à l'aide de la validation croisée). Les performances du modèle avec ces hyperparamètres sont ensuite enregistrées.
#
# 4. **Sélection du meilleur modèle :** À la fin de la recherche, PyCaret sélectionne le modèle avec les hyperparamètres qui ont donné les meilleures performances sur l'ensemble de validation.
#
# Cette approche permet une exploration efficace de l'espace des hyperparamètres sans énumérer toutes les combinaisons possibles. C'est un compromis entre l'exploration complète (grid search) et l'exploration purement aléatoire, ce qui en fait une méthode populaire pour l'optimisation des hyperparamètres.

# %% [markdown]
# ##### Instanciation du modèle

# %%
qda_model = create_model("qda")
print(qda_model)
# Out:
# <style type="text/css">
# #T_7c6c6_row5_col0, #T_7c6c6_row5_col1, #T_7c6c6_row5_col2, #T_7c6c6_row5_col3, #T_7c6c6_row5_col4, #T_7c6c6_row5_col5, #T_7c6c6_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7c6c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c6c6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7c6c6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7c6c6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7c6c6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7c6c6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7c6c6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7c6c6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c6c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c6c6_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_7c6c6_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_7c6c6_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_7c6c6_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_7c6c6_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_7c6c6_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_7c6c6_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_7c6c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c6c6_row1_col0" class="data row1 col0" >0.9524</td>
#       <td id="T_7c6c6_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_7c6c6_row1_col2" class="data row1 col2" >0.9524</td>
#       <td id="T_7c6c6_row1_col3" class="data row1 col3" >0.9583</td>
#       <td id="T_7c6c6_row1_col4" class="data row1 col4" >0.9521</td>
#       <td id="T_7c6c6_row1_col5" class="data row1 col5" >0.9286</td>
#       <td id="T_7c6c6_row1_col6" class="data row1 col6" >0.9317</td>
#     </tr>
#     <tr>
#       <th id="T_7c6c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c6c6_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_7c6c6_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_7c6c6_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_7c6c6_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_7c6c6_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_7c6c6_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_7c6c6_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_7c6c6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c6c6_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_7c6c6_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_7c6c6_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_7c6c6_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_7c6c6_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_7c6c6_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_7c6c6_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_7c6c6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c6c6_row4_col0" class="data row4 col0" >0.9048</td>
#       <td id="T_7c6c6_row4_col1" class="data row4 col1" >0.9864</td>
#       <td id="T_7c6c6_row4_col2" class="data row4 col2" >0.9048</td>
#       <td id="T_7c6c6_row4_col3" class="data row4 col3" >0.9048</td>
#       <td id="T_7c6c6_row4_col4" class="data row4 col4" >0.9048</td>
#       <td id="T_7c6c6_row4_col5" class="data row4 col5" >0.8571</td>
#       <td id="T_7c6c6_row4_col6" class="data row4 col6" >0.8571</td>
#     </tr>
#     <tr>
#       <th id="T_7c6c6_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_7c6c6_row5_col0" class="data row5 col0" >0.9714</td>
#       <td id="T_7c6c6_row5_col1" class="data row5 col1" >0.9973</td>
#       <td id="T_7c6c6_row5_col2" class="data row5 col2" >0.9714</td>
#       <td id="T_7c6c6_row5_col3" class="data row5 col3" >0.9726</td>
#       <td id="T_7c6c6_row5_col4" class="data row5 col4" >0.9714</td>
#       <td id="T_7c6c6_row5_col5" class="data row5 col5" >0.9571</td>
#       <td id="T_7c6c6_row5_col6" class="data row5 col6" >0.9578</td>
#     </tr>
#     <tr>
#       <th id="T_7c6c6_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_7c6c6_row6_col0" class="data row6 col0" >0.0381</td>
#       <td id="T_7c6c6_row6_col1" class="data row6 col1" >0.0054</td>
#       <td id="T_7c6c6_row6_col2" class="data row6 col2" >0.0381</td>
#       <td id="T_7c6c6_row6_col3" class="data row6 col3" >0.0376</td>
#       <td id="T_7c6c6_row6_col4" class="data row6 col4" >0.0381</td>
#       <td id="T_7c6c6_row6_col5" class="data row6 col5" >0.0571</td>
#       <td id="T_7c6c6_row6_col6" class="data row6 col6" >0.0568</td>
#     </tr>
#   </tbody>
# </table>
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %% [markdown]
# 1. **Accuracy (Exactitude)** : Il s'agit du rapport du nombre de prédictions correctes au nombre total d'observations. C'est une mesure générale de la performance du modèle.
#
# 2. **AUC (Area Under the ROC Curve)** : L'aire sous la courbe ROC. La courbe ROC (Receiver Operating Characteristic) est un graphique de la sensibilité par rapport à la spécificité du modèle pour différents seuils de classification. Une AUC élevée indique une bonne capacité du modèle à discriminer entre les classes.
#
# 3. **Recall (Rappel ou Sensibilité)** : Il s'agit du rapport du nombre de vrais positifs au nombre total d'observations de la classe positive. Cela mesure la capacité du modèle à identifier tous les exemples de la classe positive.
#
# 4. **Precision (Précision)** : Il s'agit du rapport du nombre de vrais positifs au nombre total de prédictions positives (vrais positifs + faux positifs). Cela mesure la précision du modèle parmi les exemples qu'il classe comme positifs.
#
# 5. **F1-score** : Il s'agit d'une moyenne pondérée de la précision et du rappel. Il est souvent utilisé comme une métrique globale qui tient compte à la fois des faux positifs et des faux négatifs.
#
# 6. **Kappa** : Le coefficient Kappa mesure l'accord entre les prédictions du modèle et les classes réelles, ajusté pour le hasard. Il fournit une mesure de la performance qui prend en compte le hasard.
#
# 7. **MCC (Matthews correlation coefficient)** : Il mesure la qualité des prédictions du modèle, en prenant en compte les quatre résultats possibles du tableau de confusion (vrais positifs, vrais négatifs, faux positifs, faux négatifs).
#
# 8. **Training Time (Temps d'entraînement)** : Le temps nécessaire pour entraîner le modèle sur les données d'entraînement.
#
# 9. **Testing Time (Temps de test)** : Le temps nécessaire pour tester le modèle sur les données de test.
#
# Ces scores vous donnent une vue d'ensemble de la performance du modèle "qda" sur les données d'entraînement. Il est important de noter que ces scores sont basés sur les données d'entraînement et ne fournissent pas nécessairement une indication de la performance sur des données nouvelles ou non vues. Vous devez toujours évaluer votre modèle sur un ensemble de test distinct pour obtenir une évaluation plus précise de sa performance réelle.

# %% [markdown]
# ##### Optimisation des paramètres du modèle

# %%
tuned_qda = tune_model(qda_model, optimize="Accuracy")
# Affichage des paramètres du modèle optimisé
print(tuned_qda)
# Out:
# <style type="text/css">
# #T_d5124_row5_col0, #T_d5124_row5_col1, #T_d5124_row5_col2, #T_d5124_row5_col3, #T_d5124_row5_col4, #T_d5124_row5_col5, #T_d5124_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d5124">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5124_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d5124_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d5124_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d5124_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d5124_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d5124_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d5124_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5124_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5124_row0_col0" class="data row0 col0" >0.9524</td>
#       <td id="T_d5124_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_d5124_row0_col2" class="data row0 col2" >0.9524</td>
#       <td id="T_d5124_row0_col3" class="data row0 col3" >0.9583</td>
#       <td id="T_d5124_row0_col4" class="data row0 col4" >0.9521</td>
#       <td id="T_d5124_row0_col5" class="data row0 col5" >0.9286</td>
#       <td id="T_d5124_row0_col6" class="data row0 col6" >0.9317</td>
#     </tr>
#     <tr>
#       <th id="T_d5124_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5124_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_d5124_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_d5124_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_d5124_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_d5124_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_d5124_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_d5124_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_d5124_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5124_row2_col0" class="data row2 col0" >0.9048</td>
#       <td id="T_d5124_row2_col1" class="data row2 col1" >0.9932</td>
#       <td id="T_d5124_row2_col2" class="data row2 col2" >0.9048</td>
#       <td id="T_d5124_row2_col3" class="data row2 col3" >0.9048</td>
#       <td id="T_d5124_row2_col4" class="data row2 col4" >0.9048</td>
#       <td id="T_d5124_row2_col5" class="data row2 col5" >0.8571</td>
#       <td id="T_d5124_row2_col6" class="data row2 col6" >0.8571</td>
#     </tr>
#     <tr>
#       <th id="T_d5124_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5124_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_d5124_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_d5124_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_d5124_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_d5124_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_d5124_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_d5124_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_d5124_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5124_row4_col0" class="data row4 col0" >0.9524</td>
#       <td id="T_d5124_row4_col1" class="data row4 col1" >0.9864</td>
#       <td id="T_d5124_row4_col2" class="data row4 col2" >0.9524</td>
#       <td id="T_d5124_row4_col3" class="data row4 col3" >0.9583</td>
#       <td id="T_d5124_row4_col4" class="data row4 col4" >0.9521</td>
#       <td id="T_d5124_row4_col5" class="data row4 col5" >0.9286</td>
#       <td id="T_d5124_row4_col6" class="data row4 col6" >0.9317</td>
#     </tr>
#     <tr>
#       <th id="T_d5124_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_d5124_row5_col0" class="data row5 col0" >0.9619</td>
#       <td id="T_d5124_row5_col1" class="data row5 col1" >0.9959</td>
#       <td id="T_d5124_row5_col2" class="data row5 col2" >0.9619</td>
#       <td id="T_d5124_row5_col3" class="data row5 col3" >0.9643</td>
#       <td id="T_d5124_row5_col4" class="data row5 col4" >0.9618</td>
#       <td id="T_d5124_row5_col5" class="data row5 col5" >0.9429</td>
#       <td id="T_d5124_row5_col6" class="data row5 col6" >0.9441</td>
#     </tr>
#     <tr>
#       <th id="T_d5124_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_d5124_row6_col0" class="data row6 col0" >0.0356</td>
#       <td id="T_d5124_row6_col1" class="data row6 col1" >0.0054</td>
#       <td id="T_d5124_row6_col2" class="data row6 col2" >0.0356</td>
#       <td id="T_d5124_row6_col3" class="data row6 col3" >0.0351</td>
#       <td id="T_d5124_row6_col4" class="data row6 col4" >0.0357</td>
#       <td id="T_d5124_row6_col5" class="data row6 col5" >0.0535</td>
#       <td id="T_d5124_row6_col6" class="data row6 col6" >0.0531</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %% [markdown]
# ##### Evaluation de l'échantillon test

# %% [markdown]
# Dans PyCaret, la fonction predict_model est utilisée pour faire des prédictions sur de nouvelles données à l'aide d'un modèle préalablement entraîné. Cette fonction prend en entrée le modèle entraîné, ainsi que les données sur lesquelles vous souhaitez faire des prédictions. Elle retourne un DataFrame contenant les prédictions du modèle sur les nouvelles données.

# %%
predict_model(tuned_qda)
# Out:
# <style type="text/css">
# </style>
# <table id="T_04b33">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04b33_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_04b33_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_04b33_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_04b33_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_04b33_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_04b33_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_04b33_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_04b33_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04b33_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04b33_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_04b33_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_04b33_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_04b33_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_04b33_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_04b33_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_04b33_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_04b33_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 136                6.3               3.4                5.6               2.4
# 142                5.8               2.7                5.1               1.9
# 39                 5.1               3.4                1.5               0.2
# 44                 5.1               3.8                1.9               0.4
# 50                 7.0               3.2                4.7               1.4
# 23                 5.1               3.3                1.7               0.5
# 90                 5.5               2.6                4.4               1.2
# 149                5.9               3.0                5.1               1.8
# 46                 5.1               3.8                1.6               0.2
# 55                 5.7               2.8                4.5               1.3
# 21                 5.1               3.7                1.5               0.4
# 147                6.5               3.0                5.2               2.0
# 47                 4.6               3.2                1.4               0.2
# 123                6.3               2.7                4.9               1.8
# 67                 5.8               2.7                4.1               1.0
# 134                6.1               2.6                5.6               1.4
# 68                 6.2               2.2                4.5               1.5
# 65                 6.7               3.1                4.4               1.4
# 51                 6.4               3.2                4.5               1.5
# 0                  5.1               3.5                1.4               0.2
# 54                 6.5               2.8                4.6               1.5
# 103                6.3               2.9                5.6               1.8
# 24                 4.8               3.4                1.9               0.2
# 81                 5.5               2.4                3.7               1.0
# 129                7.2               3.0                5.8               1.6
# 102                7.1               3.0                5.9               2.1
# 113                5.7               2.5                5.0               2.0
# 100                6.3               3.3                6.0               2.5
# 89                 5.5               2.5                4.0               1.3
# 110                6.5               3.2                5.1               2.0
# 99                 5.7               2.8                4.1               1.3
# 19                 5.1               3.8                1.5               0.3
# 6                  4.6               3.4                1.4               0.3
# 88                 5.6               3.0                4.1               1.3
# 86                 6.7               3.1                4.7               1.5
# 121                5.6               2.8                4.9               2.0
# 85                 6.0               3.4                4.5               1.6
# 37                 4.9               3.6                1.4               0.1
# 9                  4.9               3.1                1.5               0.1
# 61                 5.9               3.0                4.2               1.5
# 36                 5.5               3.5                1.3               0.2
# 109                7.2               3.6                6.1               2.5
# 3                  4.6               3.1                1.5               0.2
# 12                 4.8               3.0                1.4               0.1
# 139                6.9               3.1                5.4               2.1
#
#      target  prediction_label  prediction_score
# 136       2                 2            1.0000
# 142       2                 2            0.9995
# 39        0                 0            1.0000
# 44        0                 0            1.0000
# 50        1                 1            1.0000
# 23        0                 0            1.0000
# 90        1                 1            0.9785
# 149       2                 2            0.8512
# 46        0                 0            1.0000
# 55        1                 1            0.9882
# 21        0                 0            1.0000
# 147       2                 2            0.9997
# 47        0                 0            1.0000
# 123       2                 2            0.9904
# 67        1                 1            0.9999
# 134       2                 2            0.9994
# 68        1                 1            0.6488
# 65        1                 1            1.0000
# 51        1                 1            0.9996
# 0         0                 0            1.0000
# 54        1                 1            0.9986
# 103       2                 2            0.9701
# 24        0                 0            1.0000
# 81        1                 1            1.0000
# 129       2                 2            0.9070
# 102       2                 2            1.0000
# 113       2                 2            1.0000
# 100       2                 2            1.0000
# 89        1                 1            0.9994
# 110       2                 2            0.9981
# 99        1                 1            0.9998
# 19        0                 0            1.0000
# 6         0                 0            1.0000
# 88        1                 1            0.9996
# 86        1                 1            0.9996
# 121       2                 2            1.0000
# 85        1                 1            0.9891
# 37        0                 0            1.0000
# 9         0                 0            1.0000
# 61        1                 1            0.9985
# 36        0                 0            1.0000
# 109       2                 2            1.0000
# 3         0                 0            1.0000
# 12        0                 0            1.0000
# 139       2                 2            1.0000

# %% [markdown]
# ##### Modèle définitif pour le déploiement

# %% [markdown]
# La fonction finalize_model dans PyCaret est utilisée pour finaliser un modèle spécifique après l'entraînement. L'idée principale derrière cette fonction est de terminer le processus de modélisation en prenant le modèle entraîné, en le paramétrant avec les meilleures options, et en le prêtant à une utilisation en production ou pour la génération de prédictions sur de nouvelles données.

# %%
final_model_qda = finalize_model(qda_model)
print(final_model_qda)
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['sepal length (cm)',
#                                              'sepal width (cm)',
#                                              'petal length (cm)',
#                                              'petal width (cm)'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean',
#                                                               verbose='deprecated'))),
#                 ('categorical_i...
#                  TransformerWrapper(exclude=None, include=None,
#                                     transformer=StandardScaler(copy=True,
#                                                                with_mean=True,
#                                                                with_std=True))),
#                 ('clean_column_names',
#                  TransformerWrapper(exclude=None, include=None,
#                                     transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                 ('actual_estimator',
#                  QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                                                store_covariance=False,
#                                                tol=0.0001))],
#          verbose=False)

# %% [markdown]
# ##### Sauvegarde du modèle pour le déploiement

# %%
# save_model(final_model, "modele_pour_deploiement")

# %% [markdown]
# ## PYCARET

# %% [markdown]
# PyCaret est une bibliothèque open-source en Python qui vise à simplifier le processus de développement de modèles en automatisant de nombreuses étapes courantes. Il est conçu pour être convivial, efficace et adapté à la fois aux débutants et aux utilisateurs avancés. PyCaret peut être utilisé pour les tâches de classification, régression, clustering, et d'autres.
#
# Voici un aperçu des concepts clés de PyCaret :

# %% [markdown]
# ### Installation :

# %%
# pip install pycaret

# %%
from pycaret.classification import *
data = iris_df
exp = setup(data, target='target')
# Out:
# <style type="text/css">
# #T_84817_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_84817">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84817_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_84817_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84817_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84817_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_84817_row0_col1" class="data row0 col1" >2133</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84817_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_84817_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_84817_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_84817_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_84817_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_84817_row3_col1" class="data row3 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_84817_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_84817_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_84817_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_84817_row5_col1" class="data row5 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_84817_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_84817_row6_col1" class="data row6 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_84817_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_84817_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_84817_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_84817_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_84817_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_84817_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_84817_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_84817_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_84817_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_84817_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_84817_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_84817_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_84817_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_84817_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_84817_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_84817_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_84817_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_84817_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_84817_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_84817_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_84817_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_84817_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_84817_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_84817_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_84817_row18_col1" class="data row18 col1" >8f74</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 2. **Comparaison des modèles :**
#
#    La fonction `compare_models()` vous permet de comparer les performances de différents modèles en fonction de métriques prédéfinies.

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T
>0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_c21af_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_c21af_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_c21af_row5_col1" class="data row5 col1" >0.9627</td>
#       <td id="T_c21af_row5_col2" class="data row5 col2" >0.9976</td>
#       <td id="T_c21af_row5_col3" class="data row5 col3" >0.9627</td>
#       <td id="T_c21af_row5_col4" class="data row5 col4" >0.9711</td>
#       <td id="T_c21af_row5_col5" class="data row5 col5" >0.9619</td>
#       <td id="T_c21af_row5_col6" class="data row5 col6" >0.9436</td>
#       <td id="T_c21af_row5_col7" class="data row5 col7" >0.9483</td>
#       <td

# %% [markdown]
# 3. **Création de modèles :**
#
#
#    PyCaret fournit une interface simple pour créer différents modèles. Vous pouvez utiliser des fonctions spécifiques telles que `create_model()` pour créer un modèle spécifique ou `tune_model()` pour optimiser les hyperparamètres.

# %%
rf_model = create_model('rf')  # Random Forest
tuned_rf_model = tune_model(rf_model)
# Out:
# <style type="text/css">
# #T_d9b6a_row10_col0, #T_d9b6a_row10_col1, #T_d9b6a_row10_col2, #T_d9b6a_row10_col3, #T_d9b6a_row10_col4, #T_d9b6a_row10_col5, #T_d9b6a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d9b6a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9b6a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d9b6a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d9b6a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d9b6a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d9b6a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d9b6a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d9b6a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9b6a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9b6a_row0_col0" class="data row0 col0" >0.9091</td>
#       <td id="T_d9b6a_row0_col1" class="data row0 col1" >0.9756</td>
#       <td id="T_d9b6a_row0_col2" class="data row0 col2" >0.9091</td>
#       <td id="T_d9b6a_row0_col3" class="data row0 col3" >0.9318</td>
#       <td id="T_d9b6a_row0_col4" class="data row0 col4" >0.9091</td>
#       <td id="T_d9b6a_row0_col5" class="data row0 col5" >0.8642</td>
#       <td id="T_d9b6a_row0_col6" class="data row0 col6" >0.8750</td>
#     </tr>
#     <tr>
#       <th id="T_d9b6a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9b6a_row1_col0" class="data row1 col0" >0.9091</td>
#       <td id="T_d9b6a_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_d9b6a_row1_col2" class="data row1 col2" >0.9091</td>
#       <td id="T_d9b6a_row1_col3" class="data row1 col3" >0.9273</td>
#       <td id="T_d9b6a_row1_col4" class="data row1 col4" >0.9051</td>
#       <td id="T_d9b6a_row1_col5" class="data row1 col5" >0.8608</td>
#       <td id="T_d9b6a_row1_col6" class="data row1 col6" >0.8721</td>
#     </tr>
#     <tr>
#       <th id="T_d9b6a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9b6a_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_d9b6a_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_d9b6a_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_d9b6a_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_d9b6a_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_d9b6a_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_d9b6a_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b6a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9b6a_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_d9b6a_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_d9b6a_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_d9b6a_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_d9b6a_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_d9b6a_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_d9b6a_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b6a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9b6a_row4_col0" class="data row4 col0" >0.9091</td>
#       <td id="T_d9b6a_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_d9b6a_row4_col2" class="data row4 col2" >0.9091</td>
#       <td id="T_d9b6a_row4_col3" class="data row4 col3" >0.9273</td>
#       <td id="T_d9b6a_row4_col4" class="data row4 col4" >0.9051</td>
#       <td id="T_d9b6a_row4_col5" class="data row4 col5" >0.8608</td>
#       <td id="T_d9b6a_row4_col6" class="data row4 col6" >0.8721</td>
#     </tr>
#     <tr>
#       <th id="T_d9b6a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9b6a_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_d9b6a_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_d9b6a_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_d9b6a_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_d9b6a_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_d9b6a_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_d9b6a_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b6a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9b6a_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_d9b6a_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_d9b6a_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_d9b6a_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_d9b6a_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_d9b6a_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_d9b6a_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b6a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9b6a_row7_col0" class="data row7 col0" >0.9000</td>
#       <td id="T_d9b6a_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_d9b6a_row7_col2" class="data row7 col2" >0.9000</td>
#       <td id="T_d9b6a_row7_col3" class="data row7 col3" >0.9250</td>
#       <td id="T_d9b6a_row7_col4" class="data row7 col4" >0.9000</td>
#       <td id="T_d9b6a_row7_col5" class="data row7 col5" >0.8507</td>
#       <td id="T_d9b6a_row7_col6" class="data row7 col6" >0.8636</td>
#     </tr>
#     <tr>
#       <th id="T_d9b6a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d9b6a_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_d9b6a_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_d9b6a_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_d9b6a_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_d9b6a_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_d9b6a_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_d9b6a_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b6a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d9b6a_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_d9b6a_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_d9b6a_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_d9b6a_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_d9b6a_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_d9b6a_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_d9b6a_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_d9b6a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d9b6a_row10_col0" class="data row10 col0" >0.9627</td>
#       <td id="T_d9b6a_row10_col1" class="data row10 col1" >0.9976</td>
#       <td id="T_d9b6a_row10_col2" class="data row10 col2" >0.9627</td>
#       <td id="T_d9b6a_row10_col3" class="data row10 col3" >0.9711</td>
#       <td id="T_d9b6a_row10_col4" class="data row10 col4" >0.9619</td>
#       <td id="T_d9b6a_row10_col5" class="data row10 col5" >0.9436</td>
#       <td id="T_d9b6a_row10_col6" class="data row10 col6" >0.9483</td>
#     </tr>
#     <tr>
#       <th id="T_d9b6a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d9b6a_row11_col0" class="data row11 col0" >0.0457</td>
#       <td id="T_d9b6a_row11_col1" class="data row11 col1" >0.0073</td>
#       <td id="T_d9b6a_row11_col2" class="data row11 col2" >0.0457</td>
#       <td id="T_d9b6a_row11_col3" class="data row11 col3" >0.0354</td>
#       <td id="T_d9b6a_row11_col4
# <style type="text/css">
# #T_1dc37_row10_col0, #T_1dc37_row10_col1, #T_1dc37_row10_col2, #T_1dc37_row10_col3, #T_1dc37_row10_col4, #T_1dc37_row10_col5, #T_1dc37_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1dc37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1dc37_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1dc37_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1dc37_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1dc37_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1dc37_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1dc37_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1dc37_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1dc37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1dc37_row0_col0" class="data row0 col0" >0.9091</td>
#       <td id="T_1dc37_row0_col1" class="data row0 col1" >0.9253</td>
#       <td id="T_1dc37_row0_col2" class="data row0 col2" >0.9091</td>
#       <td id="T_1dc37_row0_col3" class="data row0 col3" >0.9318</td>
#       <td id="T_1dc37_row0_col4" class="data row0 col4" >0.9091</td>
#       <td id="T_1dc37_row0_col5" class="data row0 col5" >0.8642</td>
#       <td id="T_1dc37_row0_col6" class="data row0 col6" >0.8750</td>
#     </tr>
#     <tr>
#       <th id="T_1dc37_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1dc37_row1_col0" class="data row1 col0" >0.9091</td>
#       <td id="T_1dc37_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_1dc37_row1_col2" class="data row1 col2" >0.9091</td>
#       <td id="T_1dc37_row1_col3" class="data row1 col3" >0.9273</td>
#       <td id="T_1dc37_row1_col4" class="data row1 col4" >0.9051</td>
#       <td id="T_1dc37_row1_col5" class="data row1 col5" >0.8608</td>
#       <td id="T_1dc37_row1_col6" class="data row1 col6" >0.8721</td>
#     </tr>
#     <tr>
#       <th id="T_1dc37_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1dc37_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_1dc37_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_1dc37_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_1dc37_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_1dc37_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_1dc37_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_1dc37_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1dc37_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1dc37_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_1dc37_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_1dc37_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_1dc37_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_1dc37_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_1dc37_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_1dc37_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1dc37_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1dc37_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_1dc37_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_1dc37_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_1dc37_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_1dc37_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_1dc37_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_1dc37_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1dc37_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1dc37_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_1dc37_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_1dc37_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_1dc37_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_1dc37_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_1dc37_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_1dc37_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1dc37_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1dc37_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_1dc37_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_1dc37_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_1dc37_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_1dc37_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_1dc37_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_1dc37_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1dc37_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1dc37_row7_col0" class="data row7 col0" >0.9000</td>
#       <td id="T_1dc37_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_1dc37_row7_col2" class="data row7 col2" >0.9000</td>
#       <td id="T_1dc37_row7_col3" class="data row7 col3" >0.9250</td>
#       <td id="T_1dc37_row7_col4" class="data row7 col4" >0.9000</td>
#       <td id="T_1dc37_row7_col5" class="data row7 col5" >0.8507</td>
#       <td id="T_1dc37_row7_col6" class="data row7 col6" >0.8636</td>
#     </tr>
#     <tr>
#       <th id="T_1dc37_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1dc37_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_1dc37_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_1dc37_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_1dc37_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_1dc37_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_1dc37_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_1dc37_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1dc37_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1dc37_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_1dc37_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_1dc37_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_1dc37_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_1dc37_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_1dc37_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_1dc37_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1dc37_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_1dc37_row10_col0" class="data row10 col0" >0.9718</td>
#       <td id="T_1dc37_row10_col1" class="data row10 col1" >0.9925</td>
#       <td id="T_1dc37_row10_col2" class="data row10 col2" >0.9718</td>
#       <td id="T_1dc37_row10_col3" class="data row10 col3" >0.9784</td>
#       <td id="T_1dc37_row10_col4" class="data row10 col4" >0.9714</td>
#       <td id="T_1dc37_row10_col5" class="data row10 col5" >0.9576</td>
#       <td id="T_1dc37_row10_col6" class="data row10 col6" >0.9611</td>
#     </tr>
#     <tr>
#       <th id="T_1dc37_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_1dc37_row11_col0" class="data row11 col0" >0.0431</td>
#       <td id="T_1dc37_row11_col1" class="data row11 col1" >0.0224</td>
#       <td id="T_1dc37_row11_col2" class="data row11 col2" >0.0431</td>
#       <td id="T_1dc37_row11_col3" class="data row11 col3" >0.0330</td>
#       <td id="T_1dc37_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %% [markdown]
# 4. **Ensemble de modèles :**
#
#
#    La fonction `ensemble_model()` vous permet de créer un ensemble de modèles pour améliorer les performances prédictives.

# %%
ensembled_model = ensemble_model(rf_model)
# Out:
# <style type="text/css">
# #T_b4739_row10_col0, #T_b4739_row10_col1, #T_b4739_row10_col2, #T_b4739_row10_col3, #T_b4739_row10_col4, #T_b4739_row10_col5, #T_b4739_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_
row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_b4739_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_b4739_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_b4739_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_b4739_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b4739_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b4739_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_b4739_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_b4739_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_b4739_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_b4739_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_b4739_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_b4739_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b4739_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b4739_row10_col0" class="data row10 col0" >0.9618</td>
#       <td id="T_b4739_row10_col1" class="data row10 col1" >0.9976</td>
#       <td id="T_b4739_row10_col2" class="data row10 col2" >0.9618</td>
#       <td id="T_b4739_row10_col3" class="data row10 col3" >0.9709</td>
#       <td id="T_b4739_row10_col4" class="data row10 col4" >0.9614</td>
#       <td id="T_b4739_row10_col5" class="data row10 col5" >0.9426</td>
#       <td id="T_b4739_row10_col6" class="data row10 col6" >0.9474</td>
#     </tr>
#     <tr>
#       <th id="T_b4739_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b4739_row11_col0" class="data row11 col0" >0.0469</td>
#       <td id="T_b4739_row11_col1" class="data row11 col1" >0.0073</td>
#       <td id="T_b4739_row11_col2" class="data row11 col2" >0.0469</td>
#       <td id="T_b4739_row11_col3" class="data row11 col3" >0.0357</td>
#       <td id="T_b4739_row11_col4

# %% [markdown]
# 5. **Évaluation des modèles :**
#
#    Utilisez `evaluate_model()` pour visualiser les performances du modèle, la courbe ROC, la matrice de confusion, etc.

# %%
evaluate_model(ensembled_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# 6. **Interprétation des modèles :**
#
#    PyCaret offre des outils pour expliquer et interpréter les modèles, tels que `interpret_model()` et `plot_model()`.

# %%
# pip install shap

# %%
interpret_model(rf_model)

# %%
plot_model(rf_model, plot="feature")

# %% [markdown]
# 7. **Prédiction sur de nouvelles données :**
#
#    Utilisez la fonction `predict_model()` pour faire des prédictions sur de nouvelles données.

# %%
# new_data_predictions = predict_model(ensembled_model, data=new_data)

# %% [markdown]
# ### Avantages de PyCaret :
#
# - **Facilité d'utilisation :** PyCaret simplifie le processus de développement de modèles en automatisant plusieurs étapes, ce qui est particulièrement bénéfique pour les débutants.
#
# - **Rapidité :** La création, la comparaison et la sélection des modèles peuvent être réalisées rapidement avec des lignes de code minimales.
#
# - **Large prise en charge des modèles :** PyCaret prend en charge un grand nombre de modèles d'apprentissage automatique, offrant ainsi une grande flexibilité pour explorer différentes approches.
#
# - **Ensemble de modèles :** PyCaret facilite la création d'ensembles de modèles pour améliorer les performances globales.
#
# - **Visualisation intégrée :** La bibliothèque fournit des fonctions de visualisation intégrées pour évaluer rapidement les performances des modèles.
#
# ### Limitations :
#
# - **Personnalisation limitée :** PyCaret offre une grande automatisation, mais cela peut limiter la personnalisation pour les utilisateurs avancés qui souhaitent un contrôle fin sur chaque aspect du processus.
#
# - **Modèles standards :** Bien que PyCaret couvre un large éventail de modèles, les utilisateurs peuvent trouver que certains modèles spécifiques ne sont pas pris en charge.
#
# - **Dépendance aux données :** La performance de PyCaret dépend de la qualité des données et des caractéristiques spécifiques du problème.
#
# En résumé, PyCaret est une bibliothèque puissante pour simplifier le processus de développement de modèles, en particulier pour les tâches courantes. Il est particulièrement utile pour explorer rapidement différentes approches et modèles tout en offrant des outils pour l'interprétation et la comparaison des résultats.
